# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import requests
from bs4 import BeautifulSoup
from datetime import date
from glob import *

# %%
mydict = {
    "FC Bayern München" : "1-FC+Bayern+München",
    "Borussia Dortmund" : "5-Borussia+Dortmund",
    "Bayer Leverkusen" : "8-Bayer+04+Leverkusen",
    "RB Leipzig" : "92-RB+Leipzig",
    "FC Union Berlin" : "109-1.+FC+Union+Berlin",
    "SC Freiburg" : "21-Sport-Club+Freiburg",
    "FC Köln" : "13-1.+FC+Köln",
    "FSV Mainz 05" : "18-1.+FSV+Mainz+05",
    "TSG Hoffenheim" : "62-TSG+Hoffenheim",
    "Borussioa M'Gladbach" : "3-Borussia+M'gladbach",
    "Eintrach Frankfurt" : "9-Eintracht+Frankfurt",
    "VfL Wolfsburg" : "12-VfL+Wolfsburg",
    "VfL Bochum" : "15-VfL+Bochum",
    "FC Augsburg" : "68-FC+Augsburg",
    "VfB Stuttgart" : "14-VfB+Stuttgart",
    "Hertha BSC" : "7-Hertha+BSC",
    "FC Schalke 04" : "10-FC+Schalke+04",
    "SV Werder Bremen" : "6-SV+Werder+Bremen"
}

# %%
for x in mydict:
    print(mydict[x])
# Out:
# 1-FC+Bayern+München
# 5-Borussia+Dortmund
# 8-Bayer+04+Leverkusen
# 92-RB+Leipzig
# 109-1.+FC+Union+Berlin
# 21-Sport-Club+Freiburg
# 13-1.+FC+Köln
# 18-1.+FSV+Mainz+05
# 62-TSG+Hoffenheim
# 3-Borussia+M'gladbach
# 9-Eintracht+Frankfurt
# 12-VfL+Wolfsburg
# 15-VfL+Bochum
# 68-FC+Augsburg
# 14-VfB+Stuttgart
# 7-Hertha+BSC
# 10-FC+Schalke+04
# 6-SV+Werder+Bremen

# %%
global playerid, playername, position, punkte, pps, passq, zweikampf, marktwert, verein

playerid = []
playername = []
position = []
punkte = []
pps = []
passq = []
zweikampf = []
marktwert= []
verein = []
datum = []

# %%
def scrap(scripts, team):
    for i in range(9,len(scripts)-13):
        playerid.append(str(scripts[i]).split('data-playerid="')[1].split('">')[0])
        playername.append(str(scripts[i]).split('"_blank">')[1].split('</a><')[0])
        position.append(str(scripts[i]).split('title="')[1].split('"/><')[0])
        punkte.append(str(scripts[i]).split('<td class="base"')[1].split('<td>')[1].split('</td>')[0])
        pps.append(str(scripts[i]).split('<td class="base"')[1].split('td class="extended">')[2].split('</td>')[0])
        passq.append(str(scripts[i]).split('<td class="base"')[1].split('td class="extended">')[4].split('</td>')[0])
        zweikampf.append(str(scripts[i]).split('<td class="base"')[1].split('td class="extended">')[5].split('</td>')[0])
        marktwert.append(str(scripts[i]).split('data-value="')[1].split('"><span')[0])
        verein.append(team)
        datum.append(date.today().strftime("%d/%m/%Y"))

# %%
for x in mydict:
    team = x


    base_url = 'https://stats.comunio.de/squad/' + mydict[x]
    res = requests.get(base_url)
    soup = BeautifulSoup(res.content, 'lxml')
    scripts = soup.find_all('tr')
    scrap(scripts, team)

# %%
playerid, playername, position, punkte, pps, passq, zweikampf, marktwert, verein, datum
# Out:
# (['30755',
#   '33671',
#   '31216',
#   '33021',
#   '33074',
#   '33349',
#   '33386',
#   '33605',
#   '33660',
#   '32742',
#   '32720',
#   '33703',
#   '33626',
#   '32187',
#   '33547',
#   '32445',
#   '33236',
#   '32590',
#   '32272',
#   '32518',
#   '33633',
#   '31362',
#   '33662',
#   '31165',
#   '32696',
#   '32638',
#   '32841',
#   '33036',
#   '33396',
#   '33038',
#   '33137',
#   '33259',
#   '33432',
#   '33509',
#   '33567',
#   '31002',
#   '32632',
#   '32556',
#   '31779',
#   '32122',
#   '32546',
#   '33690',
#   '33608',
#   '32677',
#   '33497',
#   '31935',
#   '33309',
#   '32236',
#   '32208',
#   '33260',
#   '33687',
#   '33575',
#   '33569',
#   '31454',
#   '33501',
#   '33198',
#   '32197',
#   '32769',
#   '32342',
#   '32508',
#   '32007',
#   '33479',
#   '33366',
#   '33369',
#   '33125',
#   '33511',
#   '33481',
#   '32157',
#   '33499',
#   '33207',
#   '33449',
#   '33483',
#   '33189',
#   '33614',
#   '32512',
#   '32395',
#   '32155',
#   '32129',
#   '33215',
#   '33556',
#   '33619',
#   '33514',
#   '31764',
#   '33179',
#   '33122',
#   '33680',
#   '33663',
#   '32575',
#   '32481',
#   '33664',
#   '31827',
#   '33434',
#   '33433',
#   '32824',
#   '33436',
#   '33679',
#   '32581',
#   '32580',
#   '32461',
#   '31846',
#   '33540',
#   '33363',
#   '33200',
#   '33133',
#   '33023',
#   '32800',
#   '32589',
#   '31612',
#   '33180',
#   '33151',
#   '32591',
#   '32211',
#   '33091',
#   '33257',
#   '32921',
#   '33659',
#   '33609',
#   '33141',
#   '33096',
#   '31864',
#   '32883',
#   '32340',
#   '32057',
#   '32532',
#   '32073',
#   '33550',
#   '33661',
#   '32185',
#   '32310',
#   '32324',
#   '32251',
#   '32924',
#   '33641',
#   '33616',
#   '33135',
#   '33469',
#   '33411',
#   '32087',
#   '33294',
#   '32925',
#   '31881',
#   '33439',
#   '33541',
#   '33462',
#   '33461',
#   '33704',
#   '32807',
#   '32597',
#   '31910',
#   '32019',
#   '31453',
#   '31751',
#   '33677',
#   '33637',
#   '33576',
#   '31710',
#   '33458',
#   '32398',
#   '33211',
#   '33006',
#   '32071',
#   '33335',
#   '33035',
#   '31958',
#   '32861',
#   '31395',
#   '31848',
#   '33495',
#   '32356',
#   '33688',
#   '33105',
#   '33632',
#   '33642',
#   '33051',
#   '32744',
#   '33552',
#   '33686',
#   '32628',
#   '32278',
#   '33453',
#   '33562',
#   '33356',
#   '33338',
#   '32881',
#   '33621',
#   '33157',
#   '32636',
#   '32668',
#   '33615',
#   '33365',
#   '33270',
#   '33185',
#   '33100',
#   '33077',
#   '32229',
#   '31709',
#   '33466',
#   '32364',
#   '32877',
#   '33117',
#   '32989',
#   '33417',
#   '31666',
#   '32534',
#   '33478',
#   '31762',
#   '33577',
#   '33477',
#   '33409',
#   '32992',
#   '33590',
#   '32707',
#   '33654',
#   '31959',
#   '33578',
#   '33555',
#   '33538',
#   '33297',
#   '33124',
#   '32948',
#   '32544',
#   '33695',
#   '31310',
#   '33313',
#   '33397',
#   '31489',
#   '33027',
#   '33026',
#   '33669',
#   '33670',
#   '33205',
#   '33693',
#   '31416',
#   '31742',
#   '32162',
#   '32466',
#   '33437',
#   '33504',
#   '33580',
#   '33673',
#   '31349',
#   '33158',
#   '32977',
#   '32492',
#   '32680',
#   '33191',
#   '32553',
#   '32756',
#   '33536',
#   '32842',
#   '33377',
#   '33700',
#   '33692',
#   '33691',
#   '31618',
#   '32306',
#   '33306',
#   '33702',
#   '33167',
#   '33258',
#   '33319',
#   '33592',
#   '33128',
#   '31380',
#   '32311',
#   '32634',
#   '32472',
#   '32931',
#   '33450',
#   '33526',
#   '32080',
#   '33636',
#   '33353',
#   '32159',
#   '32447',
#   '33075',
#   '32944',
#   '31596',
#   '33681',
#   '32968',
#   '33618',
#   '33152',
#   '31243',
#   '33698',
#   '31458',
#   '31621',
#   '33440',
#   '33094',
#   '31220',
#   '33613',
#   '33620',
#   '33646',
#   '33675',
#   '33031',
#   '33029',
#   '32963',
#   '32653',
#   '31671',
#   '33585',
#   '31572',
#   '33678',
#   '33581',
#   '33517',
#   '33480',
#   '32792',
#   '33696',
#   '33383',
#   '31743',
#   '33586',
#   '33584',
#   '33583',
#   '32840',
#   '33472',
#   '31866',
#   '33488',
#   '33154',
#   '32949',
#   '33625',
#   '33674',
#   '33164',
#   '33120',
#   '32988',
#   '32889',
#   '33524',
#   '33325',
#   '33639',
#   '33658',
#   '33498',
#   '33553',
#   '33705',
#   '31884',
#   '32373',
#   '32280',
#   '32206',
#   '33657',
#   '32269',
#   '33607',
#   '33559',
#   '32606',
#   '33507',
#   '33160',
#   '33217',
#   '33685',
#   '33415',
#   '33414',
#   '32639',
#   '31882',
#   '33667',
#   '33653',
#   '33638',
#   '33630',
#   '33422',
#   '33420',
#   '33419',
#   '32953',
#   '32150',
#   '32428',
#   '33635',
#   '33424',
#   '33156',
#   '32965',
#   '31985',
#   '33242',
#   '33631',
#   '33676',
#   '32626',
#   '32790',
#   '33430',
#   '33429',
#   '33061',
#   '31957',
#   '32330',
#   '33012',
#   '32684',
#   '33162',
#   '33298',
#   '33134',
#   '32801',
#   '32789',
#   '33587',
#   '33452',
#   '33403',
#   '32549',
#   '33332',
#   '33129',
#   '33127',
#   '33398',
#   '31571',
#   '32956',
#   '31838',
#   '31915',
#   '32255',
#   '33701',
#   '32603',
#   '32738',
#   '32817',
#   '32572',
#   '33311',
#   '32096',
#   '32806',
#   '33683',
#   '32465',
#   '33689',
#   '33527',
#   '32656',
#   '32891',
#   '33496',
#   '33308',
#   '32452',
#   '33017',
#   '32919',
#   '32880',
#   '32526',
#   '32773',
#   '33666',
#   '33510',
#   '33444',
#   '33347',
#   '33253',
#   '33247',
#   '32830',
#   '33241',
#   '32858',
#   '33085',
#   '33652',
#   '33588',
#   '33557',
#   '33072',
#   '32667',
#   '33445',
#   '33245',
#   '33563',
#   '33513',
#   '33627',
#   '33316',
#   '33119',
#   '33617',
#   '33684',
#   '33566',
#   '32509',
#   '32049',
#   '31740',
#   '31399',
#   '33329',
#   '33650',
#   '33267',
#   '30764',
#   '33001',
#   '32527',
#   '33629',
#   '33668',
#   '33655',
#   '33561',
#   '33519',
#   '33500',
#   '33214',
#   '32983',
#   '32733',
#   '33697',
#   '30844',
#   '30988',
#   '33623',
#   '31774',
#   '33326',
#   '33384',
#   '33395',
#   '33593',
#   '33595',
#   '33596',
#   '33651',
#   '33682',
#   '33706',
#   '33226',
#   '32717',
#   '32745',
#   '33283',
#   '33656',
#   '31392',
#   '33622',
#   '33040',
#   '33301',
#   '33130',
#   '33087',
#   '31479',
#   '32190',
#   '33672',
#   '31110',
#   '33694',
#   '33699',
#   '33139',
#   '33665',
#   '32799',
#   '33647',
#   '33331',
#   '32408',
#   '32935',
#   '33224',
#   '33288',
#   '33601',
#   '33649',
#   '32754',
#   '32120',
#   '31929',
#   '32579',
#   '32562',
#   '33640',
#   '33604',
#   '31932',
#   '31519',
#   '33110',
#   '33043',
#   '32652',
#   '33364',
#   '32202',
#   '31916',
#   '32694'],
#  ['Neuer',
#   'Schenk',
#   'Ulreich',
#   'Davies',
#   'Lucas Hernández',
#   'Sarr',
#   'Stanišić',
#   'Mazraoui',
#   'de Ligt',
#   'Pavard',
#   'Upamecano',
#   'Blind',
#   'Gravenberch',
#   'Goretzka',
#   'Wanner',
#   'Kimmich',
#   'Musiala',
#   'Sabitzer',
#   'L. Sané',
#   'Coman',
#   'Mané',
#   'T. Müller',
#   'Tel',
#   'Choupo-Moting',
#   'Gnabry',
#   'Kobel',
#   'A. Meyer',
#   'Unbehaun',
#   'Lotka',
#   'N. Schlotterbeck',
#   'Mateu Morey',
#   'Meunier',
#   'S. Coulibaly',
#   'A. Papadopoulos',
#   'Rothe',
#   'Hummels',
#   'Raphaël Guerreiro',
#   'Passlack',
#   'N. Schulz',
#   'Süle',
#   'M. Wolf',
#   'Pašalić',
#   'Gürpüz',
#   'Özcan',
#   'Kamara',
#   'Can',
#   'Bellingham',
#   'Brandt',
#   'Dahoud',
#   'Moukoko',
#   'Njinmah',
#   'Adeyemi',
#   'Bynoe-Gittens',
#   'Reus',
#   'Malen',
#   'Reyna',
#   'Modeste',
#   'Haller',
#   'Hazard',
#   'Hradecky',
#   'Lomb',
#   'Lunev',
#   'Fosu-Mensah',
#   'Frimpong',
#   'Sinkgraven',
#   'Hincapié',
#   'Bakker',
#   'Tah',
#   'Kossounou ',
#   'Tapsoba',
#   'Azhil',
#   'Sertdemir',
#   'Palacios',
#   'Eze',
#   'Charles Aránguiz',
#   'Amiri',
#   'Demirbay',
#   'Andrich',
#   'Wirtz',
#   'Azmoun',
#   'Hložek',
#   'Adli',
#   'Bellarabi',
#   'Schick',
#   'Diaby',
#   'Hudson-Odoi',
#   'Nickisch',
#   'Gulácsi',
#   'Nyland',
#   'Schlieck',
#   'Blaswich',
#   'Simakan',
#   'Gvardiol',
#   'Diallo',
#   'Raum',
#   'Ba',
#   'Klostermann',
#   'Halstenberg',
#   'Henrichs',
#   'Orbán',
#   'Clark',
#   'Szoboszlai',
#   'Dani Olmo',
#   'Schlager',
#   'Haidara',
#   'Laimer',
#   'Forsberg',
#   'Kampl',
#   'André Silva',
#   'Nkunku',
#   'Y. Poulsen',
#   'Werner',
#   'Busk',
#   'L. Grill',
#   'Rönnow',
#   'Diogo Leite',
#   'Doekhi',
#   'Ryerson',
#   'Trimmel',
#   'Knoche',
#   'Jaeckel',
#   'Baumgartl',
#   'Gießelmann',
#   'Pantović',
#   'R. Khedira',
#   'Schäfer',
#   'Thorsby',
#   'Öztunali',
#   'Haberer',
#   'Haraguchi',
#   'Seguin',
#   'Möhwald',
#   'Jordan',
#   'Skarke',
#   'S. Becker',
#   'Behrens',
#   'Leweling',
#   'Michel',
#   'Maciejewski',
#   'Flekken',
#   'Uphoff',
#   'Atubolu',
#   'Siquet',
#   'Ezekwem',
#   'Sildillia',
#   'K. Schmidt',
#   'Lienhart',
#   'Kübler',
#   'Ginter',
#   'C. Günter',
#   'Gulde',
#   'J. Schmid',
#   'Röhl',
#   'Kyereh',
#   'R. Wagner',
#   'Höfler',
#   'Weißhaupt ',
#   'M. Eggestein',
#   'Keitel',
#   'Sallai',
#   'Grifo',
#   'Doan',
#   'Jeong',
#   'Gregoritsch',
#   'Höler',
#   'Petersen',
#   'T. Horn',
#   'Köbbing',
#   'Schwäbe',
#   'Smajić',
#   'Kilian',
#   'K. Pedersen',
#   'Strauch',
#   'Schindler',
#   'Hübers',
#   'Chabot',
#   'Soldo',
#   'B. Schmitz',
#   'Hector',
#   'Ljubičić',
#   'Olesen',
#   'Martel',
#   'Limnios',
#   'Maina',
#   'Huseinbašić',
#   'Skhiri',
#   'Kainz',
#   'Duda',
#   'Dietz',
#   'Tigges',
#   'Lemperle',
#   'Thielmann',
#   'S. Andersson',
#   'Adamyan',
#   'Selke',
#   'Uth',
#   'Rieß',
#   'Zentner',
#   'Dahmen',
#   'E. Fernandes',
#   'Aarón Martín',
#   'Leitsch',
#   'Bell',
#   'A. Hack',
#   'Widmer',
#   'da Costa',
#   'Caci',
#   'J. Lee',
#   'Stach',
#   'Barreiro',
#   'E. Shabani',
#   'Barkok',
#   'Fulgini',
#   'D. Kohr',
#   'Weiper',
#   'Burgzorg',
#   'Bobzien',
#   'Mustapha',
#   'Ingvartsen',
#   'Burkardt',
#   'Onisiwo',
#   'Gruda',
#   'Pentke',
#   'L. Philipp',
#   'Noll',
#   'Baumann',
#   'Lucas Ribeiro',
#   'Kabak',
#   'Nsoki',
#   'Quaresma',
#   'Angeliño',
#   'Quarshie',
#   'Vogt',
#   'Bičakčić',
#   'Akpoguma',
#   'Kadeřábek',
#   'Stiller',
#   'Bischof',
#   'F. Becker',
#   'Damar',
#   'Rudy',
#   'Skov',
#   'Baumgartner',
#   'Prömel',
#   'Geiger',
#   'Dabbur',
#   'Kramarić',
#   'Bruun Larsen',
#   'Asllani',
#   'Bebou',
#   'Rutter',
#   'Dolberg',
#   'Brüll',
#   'Dimmer',
#   'Sippel',
#   'Sommer',
#   'Olschowsky',
#   'Walde',
#   'Bensebaini',
#   'Scally',
#   'Netz',
#   'Itakura',
#   'Lainer',
#   'Jantschke',
#   'M. Friedrich',
#   'Doucouré',
#   'Elvedi',
#   'Neuhaus',
#   'Koné',
#   'Noß',
#   'Hofmann',
#   'Fraulo',
#   'Reitz',
#   'Kramer',
#   'Weigl',
#   'H. Wolf',
#   'Müsel',
#   'P. Herrmann',
#   'Ngoumou',
#   'Pléa',
#   'Borges Sanches',
#   'Thuram',
#   'Stindl',
#   'Simoni',
#   'Grahl',
#   'Trapp',
#   'Ramaj',
#   'C. Lenz',
#   'Hasebe',
#   'Smolčić',
#   'Buta',
#   'Schröder',
#   'Pellegrini',
#   'Touré',
#   'Tuta',
#   "N'Dicka",
#   'Sow',
#   'Rode',
#   'Loune',
#   'M. Götze',
#   'Dina Ebimbe',
#   'Wenig',
#   'Jakić',
#   'Lindstrøm',
#   'Kamada',
#   'Aaronson',
#   'Knauff',
#   'Chandler',
#   'Nacho Ferri',
#   'Kolo Muani',
#   'Alidou',
#   'Lucas Alario',
#   'Borré',
#   'Casteels',
#   'Schulze',
#   'Klinger',
#   'Pervan',
#   'Fischer',
#   'Lange',
#   'Bornauw',
#   'Paulo Otávio',
#   'Roussillon',
#   'Baku',
#   'van de Ven',
#   'Lacroix',
#   'Franjić',
#   'Svanberg',
#   'F. Nmecha',
#   'Paredes',
#   'Ambros',
#   'Arnold',
#   'Guilavogui',
#   'Gerhardt',
#   'Waldschmidt',
#   'Pejčinović',
#   'M. Philipp',
#   'J. Kaminski',
#   'Wind',
#   'Brekalo',
#   'P. Wimmer',
#   'L. Nmecha',
#   'Marmoush',
#   'Johansson',
#   'Grave',
#   'Riemann',
#   'Esser',
#   'Heintz',
#   'Tolba',
#   'Ordets',
#   'Janko',
#   'Oermann',
#   'Gamboa',
#   'Mašović',
#   'Lampropoulos',
#   'K. Schlotterbeck',
#   'Stafylidis',
#   'Danilo Soares',
#   'Osei-Tutu',
#   'Losilla',
#   'Osterhage',
#   'Kunde',
#   'Stöger',
#   'Förster',
#   'Góralski',
#   'Mousset',
#   'Holtmann',
#   'Asano',
#   'Bonga',
#   'Ganvoula',
#   'Antwi-Adjei',
#   'P. Hofmann',
#   'Zoller',
#   'Leneis',
#   'Gikiewicz',
#   'Koubek',
#   'Klein',
#   'M. Pedersen',
#   'Uduokhai',
#   'Oxford',
#   'Zehnter',
#   'Winther',
#   'M. Bauer',
#   'Gouweleeuw',
#   'Gumny',
#   'Iago',
#   'Vargas',
#   'Petkov',
#   'D. Caligiuri',
#   'Jensen',
#   'Baumgartlinger',
#   'Strobl',
#   'Carlos Gruezo',
#   'Engels',
#   'Dorsch',
#   'A. Maier',
#   'Rexhbecaj',
#   'Sarenren-Bazee',
#   'Demirović',
#   'Hahn',
#   'Sergio Córdova',
#   'Berisha',
#   'Niederlechner',
#   'Glaus',
#   'Schock',
#   'F. Müller',
#   'Bredlow',
#   'Ito',
#   'Mavropanos',
#   'Anton',
#   'Aidonis',
#   'B. Sosa',
#   'Vagnoman',
#   'Stenzel',
#   'Zagadou',
#   'Ulrich',
#   'Millot',
#   'Beyaz',
#   'Ahamada',
#   'Egloff',
#   'Silas',
#   'Nartey',
#   'W. Endo',
#   'Führich',
#   'Karazor',
#   'Perea',
#   'Kastanaras',
#   'Tiago Tomás',
#   'Pfeiffer',
#   'Guirassy',
#   'Kuol',
#   'T. Coulibaly',
#   'Ernst',
#   'Christensen',
#   'Kwasigroch',
#   'Zeefuik',
#   'Kenny',
#   'Uremović',
#   'Agustín Rogel',
#   'Eitschberger',
#   'Mittelstädt',
#   'Kempf',
#   'Plattenhardt',
#   'Pekarik',
#   'M. Dárdai',
#   'Šunjić',
#   'Tousart',
#   'K. Boateng',
#   'Boëtius',
#   'Serdar',
#   'Scherhant',
#   'Kanga',
#   'Ejuke',
#   'Nsona',
#   'Maolida',
#   'Jovetić',
#   'Ngankam',
#   'Lukébakio',
#   'Richter',
#   'Aksakal',
#   'Langer',
#   'Fährmann',
#   'Heekeren',
#   'Schwolow',
#   'Tauer',
#   'Aydin',
#   'Matriciani',
#   'Greiml',
#   'I. Cissé',
#   'Ouwejan',
#   'Yoshida',
#   'van den Berg',
#   'Uronen',
#   'Brunner',
#   'Kolodziejczak',
#   'M. Kaminski',
#   'Mohr',
#   'Král',
#   'Latza',
#   'Mollet',
#   'Boujellab',
#   'Zalazar',
#   'Krauß',
#   'Drexler',
#   'Polter',
#   'Karaman',
#   'Larsson',
#   'Terodde',
#   'S. Sané',
#   'Kozuki',
#   'Bülter',
#   'Lord',
#   'Pavlenka',
#   'Backhaus',
#   'Dudu ',
#   'Zetterer',
#   'Mbom',
#   'Pieper',
#   'Agu',
#   'Chiarodia',
#   'Buchanan',
#   'Friedl',
#   'N. Stark',
#   'M. Weiser',
#   'A. Jung',
#   'Veljković',
#   'Stage',
#   'Salifou',
#   'Bittencourt',
#   'C. Groß',
#   'R. Schmid',
#   'Gruev',
#   'N. Schmidt',
#   'Dinkçi',
#   'Ducksch',
#   'Füllkrug',
#   'Burke'],
#  ['Torwart',
#   'Torwart',
#   'Torwart',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Torwart',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Abwehr',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Mittelfeld',
#   'Sturm',
#   'Sturm',
#   'Sturm',
#   'Sturm'],
#  ['43',
#   '0',
#   '8',
#   '35',
#   '18',
#   '0',
#   '7',
#   '29',
#   '44',
#   '71',
#   '54',
#   '0',
#   '11',
#   '51',
#   '3',
#   '115',
#   '96',
#   '44',
#   '69',
#   '27',
#   '63',
#   '44',
#   '27',
#   '66',
#   '93',
#   '42',
#   '5',
#   '0',
#   '0',
#   '70',
#   '0',
#   '23',
#   '0',
#   '2',
#   '4',
#   '52',
#   '47',
#   '4',
#   '0',
#   '34',
#   '34',
#   '0',
#   '0',
#   '22',
#   '0',
#   '14',
#   '83',
#   '70',
#   '9',
#   '53',
#   '0',
#   '13',
#   '2',
#   '28',
#   '20',
#   '22',
#   '33',
#   '0',
#   '22',
#   '25',
#   '0',
#   '0',
#   '8',
#   '65',
#   '6',
#   '31',
#   '17',
#   '32',
#   '14',
#   '35',
#   '0',
#   '0',
#   '35',
#   '0',
#   '25',
#   '21',
#   '46',
#   '37',
#   '0',
#   '10',
#   '31',
#   '11',
#   '0',
#   '22',
#   '78',
#   '18',
#   '0',
#   '15',
#   '5',
#   '0',
#   '19',
#   '31',
#   '22',
#   '24',
#   '29',
#   '0',
#   '2',
#   '26',
#   '32',
#   '82',
#   '0',
#   '63',
#   '35',
#   '26',
#   '16',
#   '7',
#   '29',
#   '28',
#   '40',
#   '102',
#   '7',
#   '34',
#   '0',
#   '-5',
#   '42',
#   '26',
#   '26',
#   '34',
#   '32',
#   '38',
#   '19',
#   '5',
#   '28',
#   '12',
#   '26',
#   '14',
#   '15',
#   '0',
#   '40',
#   '16',
#   '16',
#   '0',
#   '48',
#   '0',
#   '81',
#   '40',
#   '6',
#   '31',
#   '0',
#   '55',
#   '0',
#   '0',
#   '1',
#   '0',
#   '28',
#   '0',
#   '43',
#   '31',
#   '74',
#   '40',
#   '4',
#   '0',
#   '0',
#   '17',
#   '0',
#   '39',
#   '12',
#   '35',
#   '12',
#   '15',
#   '116',
#   '42',
#   '21',
#   '78',
#   '5',
#   '13',
#   '0',
#   '0',
#   '12',
#   '0',
#   '10',
#   '6',
#   '0',
#   '12',
#   '22',
#   '10',
#   '5',
#   '35',
#   '45',
#   '40',
#   '5',
#   '19',
#   '0',
#   '30',
#   '20',
#   '45',
#   '81',
#   '8',
#   '13',
#   '35',
#   '1',
#   '21',
#   '0',
#   '17',
#   '26',
#   '4',
#   '0',
#   '33',
#   '0',
#   '30',
#   '70',
#   '13',
#   '25',
#   '17',
#   '36',
#   '12',
#   '27',
#   '46',
#   '51',
#   '19',
#   '0',
#   '8',
#   '13',
#   '42',
#   '1',
#   '9',
#   '0',
#   '4',
#   '33',
#   '27',
#   '55',
#   '0',
#   '0',
#   '0',
#   '0',
#   '45',
#   '0',
#   '62',
#   '9',
#   '5',
#   '53',
#   '0',
#   '34',
#   '0',
#   '30',
#   '27',
#   '17',
#   '1',
#   '0',
#   '4',
#   '16',
#   '53',
#   '61',
#   '32',
#   '45',
#   '39',
#   '41',
#   '11',
#   '1',
#   '0',
#   '32',
#   '0',
#   '0',
#   '0',
#   '-2',
#   '44',
#   '8',
#   '0',
#   '87',
#   '24',
#   '3',
#   '12',
#   '0',
#   '4',
#   '30',
#   '0',
#   '50',
#   '13',
#   '40',
#   '0',
#   '88',
#   '0',
#   '0',
#   '9',
#   '28',
#   '2',
#   '0',
#   '18',
#   '4',
#   '50',
#   '4',
#   '92',
#   '34',
#   '0',
#   '0',
#   '22',
#   '0',
#   '27',
#   '9',
#   '9',
#   '0',
#   '0',
#   '30',
#   '4',
#   '30',
#   '33',
#   '50',
#   '40',
#   '0',
#   '61',
#   '29',
#   '0',
#   '32',
#   '54',
#   '75',
#   '0',
#   '22',
#   '2',
#   '0',
#   '59',
#   '7',
#   '16',
#   '24',
#   '58',
#   '0',
#   '0',
#   '0',
#   '2',
#   '0',
#   '17',
#   '49',
#   '2',
#   '62',
#   '40',
#   '28',
#   '8',
#   '19',
#   '45',
#   '10',
#   '0',
#   '97',
#   '21',
#   '30',
#   '6',
#   '0',
#   '6',
#   '8',
#   '14',
#   '8',
#   '25',
#   '43',
#   '21',
#   '0',
#   '0',
#   '41',
#   '0',
#   '-1',
#   '0',
#   '21',
#   '0',
#   '-2',
#   '27',
#   '16',
#   '5',
#   '5',
#   '19',
#   '16',
#   '12',
#   '25',
#   '4',
#   '0',
#   '56',
#   '29',
#   '4',
#   '0',
#   '32',
#   '3',
#   '0',
#   '13',
#   '34',
#   '62',
#   '37',
#   '0',
#   '49',
#   '10',
#   '0',
#   '21',
#   '10',
#   '6',
#   '0',
#   '2',
#   '18',
#   '29',
#   '23',
#   '12',
#   '20',
#   '4',
#   '17',
#   '22',
#   '7',
#   '0',
#   '22',
#   '0',
#   '0',
#   '14',
#   '18',
#   '0',
#   '56',
#   '21',
#   '0',
#   '35',
#   '49',
#   '0',
#   '0',
#   '22',
#   '0',
#   '33',
#   '81',
#   '42',
#   '0',
#   '46',
#   '4',
#   '18',
#   '11',
#   '1',
#   '17',
#   '0',
#   '35',
#   '14',
#   '30',
#   '3',
#   '58',
#   '45',
#   '24',
#   '7',
#   '0',
#   '35',
#   '5',
#   '39',
#   '0',
#   '3',
#   '0',
#   '33',
#   '0',
#   '0',
#   '38',
#   '7',
#   '12',
#   '0',
#   '15',
#   '53',
#   '30',
#   '1',
#   '7',
#   '22',
#   '39',
#   '-2',
#   '14',
#   '47',
#   '1',
#   '35',
#   '27',
#   '0',
#   '-1',
#   '25',
#   '0',
#   '79',
#   '43',
#   '0',
#   '0',
#   '0',
#   '0',
#   '26',
#   '2',
#   '9',
#   '16',
#   '2',
#   '0',
#   '25',
#   '37',
#   '7',
#   '0',
#   '23',
#   '1',
#   '3',
#   '33',
#   '19',
#   '7',
#   '12',
#   '0',
#   '11',
#   '45',
#   '18',
#   '27',
#   '1',
#   '9',
#   '44',
#   '0',
#   '0',
#   '33',
#   '0',
#   '35',
#   '0',
#   '0',
#   '5',
#   '0',
#   '31',
#   '-2',
#   '1',
#   '22',
#   '32',
#   '25',
#   '60',
#   '44',
#   '42',
#   '16',
#   '0',
#   '27',
#   '21',
#   '19',
#   '21',
#   '20',
#   '5',
#   '71',
#   '97',
#   '27'],
#  ['3,58',
#   '-',
#   '2,67',
#   '2,92',
#   '2,57',
#   '-',
#   '1,17',
#   '2,64',
#   '3,67',
#   '5,46',
#   '3,60',
#   '-',
#   '1,10',
#   '4,64',
#   '3,00',
#   '7,67',
#   '6,86',
#   '3,14',
#   '5,31',
#   '3,00',
#   '4,50',
#   '5,50',
#   '3,86',
#   '6,60',
#   '6,20',
#   '3,82',
#   '1,25',
#   '-',
#   '-',
#   '4,67',
#   '-',
#   '2,88',
#   '-',
#   '2,00',
#   '4,00',
#   '4,00',
#   '3,92',
#   '2,00',
#   '-',
#   '2,83',
#   '3,40',
#   '0,00',
#   '-',
#   '1,83',
#   '-',
#   '1,56',
#   '5,53',
#   '4,67',
#   '3,00',
#   '4,08',
#   '0,00',
#   '1,18',
#   '0,50',
#   '3,11',
#   '2,00',
#   '2,20',
#   '2,54',
#   '-',
#   '1,69',
#   '1,79',
#   '-',
#   '0,00',
#   '1,60',
#   '4,33',
#   '1,50',
#   '2,38',
#   '1,31',
#   '2,13',
#   '1,40',
#   '2,33',
#   '-',
#   '-',
#   '3,50',
#   '-',
#   '2,50',
#   '1,91',
#   '3,29',
#   '2,85',
#   '-',
#   '1,25',
#   '2,38',
#   '1,38',
#   '0,00',
#   '2,00',
#   '5,20',
#   '2,00',
#   '-',
#   '2,50',
#   '5,00',
#   '-',
#   '2,38',
#   '3,10',
#   '1,69',
#   '4,80',
#   '2,07',
#   '-',
#   '2,00',
#   '2,17',
#   '2,29',
#   '5,47',
#   '-',
#   '4,85',
#   '3,50',
#   '2,36',
#   '1,33',
#   '1,75',
#   '2,42',
#   '2,00',
#   '2,86',
#   '6,80',
#   '1,17',
#   '3,78',
#   '-',
#   '-1,25',
#   '3,82',
#   '2,00',
#   '4,33',
#   '2,62',
#   '2,46',
#   '2,71',
#   '1,90',
#   '1,25',
#   '2,55',
#   '1,50',
#   '1,86',
#   '1,27',
#   '1,36',
#   '-',
#   '3,08',
#   '2,00',
#   '2,29',
#   '-',
#   '3,69',
#   '0,00',
#   '5,40',
#   '2,67',
#   '1,00',
#   '2,82',
#   '-',
#   '3,67',
#   '-',
#   '-',
#   '1,00',
#   '-',
#   '2,00',
#   '-',
#   '2,87',
#   '6,20',
#   '4,93',
#   '2,67',
#   '1,33',
#   '-',
#   '-',
#   '1,89',
#   '0,00',
#   '2,60',
#   '1,50',
#   '2,69',
#   '1,33',
#   '2,14',
#   '7,73',
#   '2,80',
#   '1,62',
#   '5,20',
#   '0,71',
#   '1,30',
#   '-',
#   '-',
#   '0,80',
#   '-',
#   '0,77',
#   '1,20',
#   '-',
#   '0,86',
#   '1,83',
#   '5,00',
#   '1,00',
#   '2,50',
#   '3,46',
#   '4,44',
#   '1,67',
#   '1,73',
#   '-',
#   '2,14',
#   '2,50',
#   '3,21',
#   '5,79',
#   '0,62',
#   '1,30',
#   '2,92',
#   '0,33',
#   '2,10',
#   '-',
#   '1,31',
#   '2,17',
#   '1,33',
#   '-',
#   '2,20',
#   '-',
#   '2,31',
#   '4,67',
#   '1,86',
#   '1,92',
#   '1,31',
#   '2,77',
#   '1,50',
#   '2,45',
#   '3,07',
#   '3,92',
#   '1,58',
#   '-',
#   '1,33',
#   '0,93',
#   '3,00',
#   '1,00',
#   '0,90',
#   '-',
#   '1,00',
#   '3,67',
#   '2,45',
#   '3,67',
#   '-',
#   '-',
#   '-',
#   '-',
#   '3,00',
#   '-',
#   '4,43',
#   '1,00',
#   '1,67',
#   '3,79',
#   '-',
#   '2,43',
#   '-',
#   '2,31',
#   '2,08',
#   '1,89',
#   '1,00',
#   '-',
#   '1,00',
#   '1,60',
#   '3,79',
#   '4,07',
#   '2,46',
#   '3,21',
#   '3,90',
#   '2,93',
#   '1,10',
#   '0,33',
#   '-',
#   '2,13',
#   '-',
#   '-',
#   '-',
#   '-0,67',
#   '4,40',
#   '4,00',
#   '-',
#   '6,21',
#   '1,60',
#   '0,75',
#   '2,40',
#   '0,00',
#   '2,00',
#   '2,50',
#   '-',
#   '3,85',
#   '2,17',
#   '2,86',
#   '-',
#   '6,77',
#   '-',
#   '-',
#   '0,64',
#   '2,55',
#   '1,00',
#   '-',
#   '2,25',
#   '0,67',
#   '4,55',
#   '1,33',
#   '6,13',
#   '3,09',
#   '-',
#   '-',
#   '1,47',
#   '-',
#   '3,00',
#   '2,25',
#   '2,25',
#   '-',
#   '-',
#   '3,33',
#   '2,00',
#   '2,00',
#   '2,20',
#   '3,33',
#   '3,33',
#   '-',
#   '4,07',
#   '2,90',
#   '-',
#   '2,29',
#   '3,86',
#   '5,77',
#   '-',
#   '2,00',
#   '0,67',
#   '-',
#   '4,21',
#   '0,88',
#   '2,29',
#   '1,71',
#   '3,87',
#   '-',
#   '-',
#   '-',
#   '0,67',
#   '-',
#   '1,70',
#   '3,77',
#   '1,00',
#   '4,13',
#   '2,67',
#   '3,11',
#   '2,67',
#   '1,36',
#   '3,46',
#   '1,43',
#   '-',
#   '6,47',
#   '2,33',
#   '3,33',
#   '1,00',
#   '-',
#   '2,00',
#   '0,62',
#   '2,80',
#   '1,33',
#   '3,13',
#   '3,58',
#   '1,50',
#   '-',
#   '-',
#   '2,73',
#   '-',
#   '-0,25',
#   '-',
#   '1,50',
#   '0,00',
#   '-0,50',
#   '1,80',
#   '1,45',
#   '0,83',
#   '2,50',
#   '2,38',
#   '1,60',
#   '1,00',
#   '1,67',
#   '0,40',
#   '-',
#   '4,00',
#   '2,64',
#   '1,33',
#   '-',
#   '2,46',
#   '0,60',
#   '-',
#   '1,63',
#   '3,40',
#   '4,13',
#   '2,64',
#   '-',
#   '4,45',
#   '2,50',
#   '-',
#   '1,75',
#   '1,43',
#   '2,00',
#   '-',
#   '2,00',
#   '1,29',
#   '2,07',
#   '2,09',
#   '0,92',
#   '1,82',
#   '0,67',
#   '2,13',
#   '2,00',
#   '1,17',
#   '-',
#   '1,69',
#   '-',
#   '-',
#   '1,40',
#   '1,29',
#   '-',
#   '3,73',
#   '3,00',
#   '-',
#   '3,50',
#   '3,50',
#   '-',
#   '-',
#   '1,47',
#   '-',
#   '2,54',
#   '6,23',
#   '2,80',
#   '-',
#   '3,83',
#   '0,50',
#   '2,25',
#   '1,83',
#   '1,00',
#   '1,70',
#   '-',
#   '2,33',
#   '1,75',
#   '2,14',
#   '1,50',
#   '4,14',
#   '3,21',
#   '2,40',
#   '0,88',
#   '0,00',
#   '2,69',
#   '0,45',
#   '3,90',
#   '-',
#   '3,00',
#   '-',
#   '2,20',
#   '-',
#   '-',
#   '2,53',
#   '1,00',
#   '1,50',
#   '-',
#   '2,50',
#   '3,53',
#   '2,31',
#   '1,00',
#   '1,17',
#   '1,69',
#   '2,79',
#   '-0,29',
#   '1,40',
#   '3,36',
#   '0,50',
#   '2,50',
#   '1,80',
#   '-',
#   '-0,50',
#   '3,13',
#   '-',
#   '5,27',
#   '3,58',
#   '-',
#   '-',
#   '-',
#   '-',
#   '1,73',
#   '0,67',
#   '1,29',
#   '2,00',
#   '0,50',
#   '-',
#   '2,50',
#   '2,47',
#   '1,75',
#   '-',
#   '1,92',
#   '1,00',
#   '3,00',
#   '3,00',
#   '1,58',
#   '0,78',
#   '1,33',
#   '-',
#   '1,38',
#   '3,00',
#   '1,50',
#   '1,93',
#   '0,11',
#   '1,00',
#   '2,93',
#   '-',
#   '-',
#   '2,20',
#   '-',
#   '2,33',
#   '-',
#   '-',
#   '5,00',
#   '-',
#   '2,38',
#   '-0,67',
#   '1,00',
#   '2,44',
#   '2,29',
#   '2,78',
#   '4,00',
#   '2,93',
#   '3,50',
#   '1,23',
#   '-',
#   '2,70',
#   '1,62',
#   '1,36',
#   '1,62',
#   '3,33',
#   '1,67',
#   '4,73',
#   '6,93',
#   '2,08'],
#  ['87%',
#   '-',
#   '81%',
#   '89%',
#   '91%',
#   '-',
#   '92%',
#   '88%',
#   '92%',
#   '89%',
#   '91%',
#   '-',
#   '88%',
#   '83%',
#   '71%',
#   '89%',
#   '85%',
#   '88%',
#   '84%',
#   '86%',
#   '75%',
#   '79%',
#   '85%',
#   '76%',
#   '83%',
#   '81%',
#   '88%',
#   '-',
#   '-',
#   '87%',
#   '-',
#   '72%',
#   '-',
#   '89%',
#   '100%',
#   '88%',
#   '86%',
#   '73%',
#   '-',
#   '89%',
#   '73%',
#   '100%',
#   '-',
#   '88%',
#   '-',
#   '89%',
#   '83%',
#   '83%',
#   '78%',
#   '72%',
#   '0%',
#   '75%',
#   '79%',
#   '78%',
#   '78%',
#   '75%',
#   '62%',
#   '-',
#   '80%',
#   '70%',
#   '-',
#   '76%',
#   '80%',
#   '79%',
#   '71%',
#   '83%',
#   '77%',
#   '89%',
#   '83%',
#   '86%',
#   '-',
#   '-',
#   '85%',
#   '-',
#   '83%',
#   '83%',
#   '79%',
#   '84%',
#   '-',
#   '59%',
#   '83%',
#   '83%',
#   '62%',
#   '71%',
#   '81%',
#   '88%',
#   '-',
#   '85%',
#   '88%',
#   '-',
#   '84%',
#   '85%',
#   '90%',
#   '86%',
#   '81%',
#   '-',
#   '75%',
#   '85%',
#   '73%',
#   '89%',
#   '-',
#   '83%',
#   '80%',
#   '87%',
#   '83%',
#   '77%',
#   '86%',
#   '91%',
#   '74%',
#   '82%',
#   '42%',
#   '75%',
#   '-',
#   '66%',
#   '67%',
#   '80%',
#   '81%',
#   '73%',
#   '64%',
#   '81%',
#   '80%',
#   '83%',
#   '75%',
#   '69%',
#   '75%',
#   '76%',
#   '68%',
#   '-',
#   '69%',
#   '81%',
#   '77%',
#   '-',
#   '53%',
#   '71%',
#   '69%',
#   '63%',
#   '88%',
#   '61%',
#   '-',
#   '72%',
#   '-',
#   '-',
#   '83%',
#   '-',
#   '75%',
#   '-',
#   '86%',
#   '70%',
#   '84%',
#   '77%',
#   '83%',
#   '-',
#   '-',
#   '81%',
#   '100%',
#   '85%',
#   '59%',
#   '79%',
#   '83%',
#   '76%',
#   '80%',
#   '74%',
#   '80%',
#   '56%',
#   '59%',
#   '50%',
#   '-',
#   '-',
#   '80%',
#   '-',
#   '86%',
#   '75%',
#   '-',
#   '67%',
#   '83%',
#   '88%',
#   '78%',
#   '63%',
#   '78%',
#   '82%',
#   '73%',
#   '81%',
#   '-',
#   '74%',
#   '85%',
#   '89%',
#   '73%',
#   '78%',
#   '58%',
#   '60%',
#   '60%',
#   '69%',
#   '-',
#   '74%',
#   '60%',
#   '83%',
#   '-',
#   '48%',
#   '-',
#   '75%',
#   '83%',
#   '77%',
#   '81%',
#   '74%',
#   '75%',
#   '65%',
#   '74%',
#   '77%',
#   '69%',
#   '70%',
#   '-',
#   '82%',
#   '82%',
#   '73%',
#   '100%',
#   '71%',
#   '-',
#   '53%',
#   '66%',
#   '73%',
#   '62%',
#   '-',
#   '-',
#   '-',
#   '-',
#   '80%',
#   '-',
#   '85%',
#   '81%',
#   '88%',
#   '70%',
#   '-',
#   '90%',
#   '-',
#   '79%',
#   '70%',
#   '78%',
#   '75%',
#   '-',
#   '81%',
#   '79%',
#   '72%',
#   '73%',
#   '78%',
#   '86%',
#   '76%',
#   '81%',
#   '77%',
#   '62%',
#   '-',
#   '64%',
#   '-',
#   '-',
#   '-',
#   '63%',
#   '81%',
#   '75%',
#   '-',
#   '77%',
#   '77%',
#   '69%',
#   '91%',
#   '68%',
#   '89%',
#   '86%',
#   '-',
#   '92%',
#   '75%',
#   '87%',
#   '-',
#   '79%',
#   '-',
#   '100%',
#   '84%',
#   '88%',
#   '71%',
#   '-',
#   '69%',
#   '71%',
#   '72%',
#   '83%',
#   '74%',
#   '79%',
#   '-',
#   '-',
#   '60%',
#   '-',
#   '81%',
#   '85%',
#   '77%',
#   '-',
#   '-',
#   '73%',
#   '81%',
#   '81%',
#   '86%',
#   '86%',
#   '87%',
#   '-',
#   '78%',
#   '72%',
#   '90%',
#   '77%',
#   '70%',
#   '84%',
#   '-',
#   '65%',
#   '61%',
#   '-',
#   '66%',
#   '78%',
#   '70%',
#   '77%',
#   '74%',
#   '-',
#   '-',
#   '-',
#   '76%',
#   '-',
#   '82%',
#   '76%',
#   '50%',
#   '79%',
#   '89%',
#   '87%',
#   '77%',
#   '72%',
#   '70%',
#   '78%',
#   '-',
#   '81%',
#   '79%',
#   '75%',
#   '76%',
#   '-',
#   '76%',
#   '73%',
#   '68%',
#   '74%',
#   '63%',
#   '65%',
#   '66%',
#   '-',
#   '-',
#   '59%',
#   '-',
#   '89%',
#   '-',
#   '73%',
#   '81%',
#   '78%',
#   '68%',
#   '84%',
#   '68%',
#   '100%',
#   '80%',
#   '73%',
#   '76%',
#   '71%',
#   '67%',
#   '-',
#   '75%',
#   '80%',
#   '78%',
#   '-',
#   '70%',
#   '82%',
#   '-',
#   '58%',
#   '67%',
#   '61%',
#   '62%',
#   '-',
#   '61%',
#   '61%',
#   '-',
#   '70%',
#   '73%',
#   '57%',
#   '-',
#   '65%',
#   '72%',
#   '66%',
#   '61%',
#   '63%',
#   '53%',
#   '52%',
#   '63%',
#   '60%',
#   '85%',
#   '-',
#   '74%',
#   '-',
#   '-',
#   '77%',
#   '60%',
#   '-',
#   '47%',
#   '47%',
#   '-',
#   '51%',
#   '61%',
#   '-',
#   '-',
#   '80%',
#   '-',
#   '82%',
#   '80%',
#   '82%',
#   '-',
#   '79%',
#   '78%',
#   '76%',
#   '84%',
#   '100%',
#   '84%',
#   '-',
#   '86%',
#   '61%',
#   '79%',
#   '77%',
#   '76%',
#   '80%',
#   '84%',
#   '84%',
#   '100%',
#   '62%',
#   '62%',
#   '68%',
#   '-',
#   '80%',
#   '-',
#   '67%',
#   '-',
#   '-',
#   '75%',
#   '82%',
#   '77%',
#   '-',
#   '80%',
#   '78%',
#   '75%',
#   '75%',
#   '61%',
#   '77%',
#   '66%',
#   '84%',
#   '74%',
#   '73%',
#   '71%',
#   '65%',
#   '82%',
#   '-',
#   '38%',
#   '62%',
#   '-',
#   '73%',
#   '69%',
#   '-',
#   '-',
#   '-',
#   '-',
#   '60%',
#   '87%',
#   '66%',
#   '75%',
#   '82%',
#   '-',
#   '69%',
#   '79%',
#   '83%',
#   '-',
#   '74%',
#   '85%',
#   '81%',
#   '67%',
#   '70%',
#   '74%',
#   '79%',
#   '-',
#   '67%',
#   '75%',
#   '67%',
#   '58%',
#   '69%',
#   '74%',
#   '67%',
#   '-',
#   '-',
#   '68%',
#   '-',
#   '67%',
#   '-',
#   '-',
#   '54%',
#   '-',
#   '78%',
#   '74%',
#   '0%',
#   '73%',
#   '83%',
#   '82%',
#   '71%',
#   '79%',
#   '81%',
#   '63%',
#   '-',
#   '77%',
#   '82%',
#   '77%',
#   '87%',
#   '78%',
#   '53%',
#   '72%',
#   '62%',
#   '71%'],
#  ['83%',
#   '-',
#   '67%',
#   '55%',
#   '63%',
#   '-',
#   '58%',
#   '57%',
#   '54%',
#   '66%',
#   '59%',
#   '-',
#   '45%',
#   '58%',
#   '67%',
#   '53%',
#   '45%',
#   '55%',
#   '51%',
#   '45%',
#   '48%',
#   '50%',
#   '43%',
#   '55%',
#   '39%',
#   '100%',
#   '50%',
#   '-',
#   '-',
#   '68%',
#   '-',
#   '52%',
#   '-',
#   '33%',
#   '100%',
#   '59%',
#   '59%',
#   '80%',
#   '-',
#   '56%',
#   '57%',
#   '33%',
#   '-',
#   '49%',
#   '-',
#   '56%',
#   '60%',
#   '45%',
#   '56%',
#   '43%',
#   '50%',
#   '42%',
#   '35%',
#   '42%',
#   '42%',
#   '46%',
#   '38%',
#   '-',
#   '44%',
#   '100%',
#   '-',
#   '-',
#   '58%',
#   '55%',
#   '47%',
#   '53%',
#   '45%',
#   '54%',
#   '55%',
#   '59%',
#   '-',
#   '-',
#   '57%',
#   '-',
#   '56%',
#   '48%',
#   '36%',
#   '57%',
#   '-',
#   '38%',
#   '39%',
#   '37%',
#   '50%',
#   '43%',
#   '38%',
#   '58%',
#   '-',
#   '-',
#   '-',
#   '-',
#   '100%',
#   '50%',
#   '60%',
#   '56%',
#   '46%',
#   '-',
#   '71%',
#   '56%',
#   '61%',
#   '62%',
#   '-',
#   '47%',
#   '45%',
#   '46%',
#   '30%',
#   '50%',
#   '46%',
#   '45%',
#   '41%',
#   '43%',
#   '55%',
#   '31%',
#   '-',
#   '67%',
#   '75%',
#   '57%',
#   '61%',
#   '49%',
#   '47%',
#   '60%',
#   '42%',
#   '62%',
#   '45%',
#   '48%',
#   '50%',
#   '46%',
#   '44%',
#   '0%',
#   '39%',
#   '69%',
#   '52%',
#   '-',
#   '44%',
#   '27%',
#   '29%',
#   '52%',
#   '41%',
#   '40%',
#   '-',
#   '86%',
#   '-',
#   '-',
#   '75%',
#   '-',
#   '44%',
#   '-',
#   '67%',
#   '51%',
#   '66%',
#   '38%',
#   '50%',
#   '-',
#   '-',
#   '43%',
#   '0%',
#   '57%',
#   '53%',
#   '55%',
#   '42%',
#   '56%',
#   '54%',
#   '44%',
#   '39%',
#   '50%',
#   '36%',
#   '29%',
#   '-',
#   '-',
#   '100%',
#   '-',
#   '57%',
#   '59%',
#   '-',
#   '53%',
#   '57%',
#   '58%',
#   '50%',
#   '58%',
#   '69%',
#   '42%',
#   '60%',
#   '54%',
#   '-',
#   '40%',
#   '39%',
#   '57%',
#   '44%',
#   '40%',
#   '42%',
#   '44%',
#   '17%',
#   '48%',
#   '-',
#   '27%',
#   '46%',
#   '60%',
#   '-',
#   '86%',
#   '-',
#   '54%',
#   '51%',
#   '67%',
#   '48%',
#   '54%',
#   '57%',
#   '50%',
#   '47%',
#   '49%',
#   '60%',
#   '53%',
#   '-',
#   '38%',
#   '41%',
#   '52%',
#   '-',
#   '31%',
#   '-',
#   '46%',
#   '34%',
#   '42%',
#   '36%',
#   '-',
#   '-',
#   '-',
#   '-',
#   '100%',
#   '-',
#   '58%',
#   '52%',
#   '73%',
#   '54%',
#   '-',
#   '47%',
#   '-',
#   '54%',
#   '55%',
#   '64%',
#   '0%',
#   '-',
#   '32%',
#   '46%',
#   '45%',
#   '41%',
#   '52%',
#   '46%',
#   '33%',
#   '47%',
#   '33%',
#   '33%',
#   '-',
#   '39%',
#   '-',
#   '-',
#   '-',
#   '67%',
#   '67%',
#   '0%',
#   '-',
#   '62%',
#   '68%',
#   '53%',
#   '52%',
#   '33%',
#   '67%',
#   '72%',
#   '-',
#   '74%',
#   '38%',
#   '56%',
#   '-',
#   '46%',
#   '-',
#   '-',
#   '42%',
#   '69%',
#   '63%',
#   '-',
#   '41%',
#   '44%',
#   '42%',
#   '50%',
#   '45%',
#   '38%',
#   '-',
#   '-',
#   '100%',
#   '-',
#   '55%',
#   '67%',
#   '87%',
#   '-',
#   '-',
#   '56%',
#   '71%',
#   '45%',
#   '55%',
#   '59%',
#   '53%',
#   '-',
#   '44%',
#   '48%',
#   '-',
#   '49%',
#   '35%',
#   '45%',
#   '-',
#   '52%',
#   '60%',
#   '-',
#   '39%',
#   '32%',
#   '38%',
#   '40%',
#   '100%',
#   '-',
#   '-',
#   '-',
#   '44%',
#   '-',
#   '45%',
#   '58%',
#   '20%',
#   '52%',
#   '61%',
#   '57%',
#   '65%',
#   '48%',
#   '63%',
#   '50%',
#   '-',
#   '66%',
#   '48%',
#   '37%',
#   '41%',
#   '-',
#   '67%',
#   '34%',
#   '65%',
#   '36%',
#   '40%',
#   '58%',
#   '42%',
#   '-',
#   '-',
#   '78%',
#   '-',
#   '43%',
#   '-',
#   '62%',
#   '46%',
#   '43%',
#   '61%',
#   '53%',
#   '55%',
#   '100%',
#   '62%',
#   '61%',
#   '49%',
#   '51%',
#   '33%',
#   '-',
#   '48%',
#   '49%',
#   '60%',
#   '-',
#   '40%',
#   '34%',
#   '-',
#   '52%',
#   '32%',
#   '51%',
#   '38%',
#   '-',
#   '100%',
#   '100%',
#   '-',
#   '48%',
#   '45%',
#   '59%',
#   '-',
#   '54%',
#   '61%',
#   '56%',
#   '45%',
#   '42%',
#   '49%',
#   '35%',
#   '42%',
#   '37%',
#   '52%',
#   '-',
#   '57%',
#   '-',
#   '-',
#   '43%',
#   '58%',
#   '-',
#   '37%',
#   '48%',
#   '-',
#   '35%',
#   '42%',
#   '-',
#   '-',
#   '100%',
#   '-',
#   '49%',
#   '66%',
#   '56%',
#   '-',
#   '54%',
#   '50%',
#   '65%',
#   '50%',
#   '100%',
#   '44%',
#   '-',
#   '49%',
#   '60%',
#   '41%',
#   '60%',
#   '60%',
#   '51%',
#   '63%',
#   '36%',
#   '0%',
#   '44%',
#   '43%',
#   '55%',
#   '-',
#   '100%',
#   '-',
#   '73%',
#   '-',
#   '-',
#   '55%',
#   '57%',
#   '55%',
#   '-',
#   '54%',
#   '61%',
#   '54%',
#   '0%',
#   '60%',
#   '54%',
#   '54%',
#   '15%',
#   '53%',
#   '53%',
#   '25%',
#   '42%',
#   '44%',
#   '-',
#   '18%',
#   '50%',
#   '-',
#   '43%',
#   '44%',
#   '-',
#   '-',
#   '-',
#   '-',
#   '83%',
#   '44%',
#   '48%',
#   '61%',
#   '42%',
#   '-',
#   '58%',
#   '67%',
#   '45%',
#   '-',
#   '47%',
#   '0%',
#   '0%',
#   '45%',
#   '51%',
#   '40%',
#   '30%',
#   '-',
#   '44%',
#   '55%',
#   '43%',
#   '42%',
#   '45%',
#   '41%',
#   '36%',
#   '-',
#   '-',
#   '41%',
#   '-',
#   '63%',
#   '-',
#   '-',
#   '100%',
#   '-',
#   '68%',
#   '38%',
#   '100%',
#   '44%',
#   '60%',
#   '55%',
#   '51%',
#   '53%',
#   '61%',
#   '51%',
#   '-',
#   '45%',
#   '44%',
#   '44%',
#   '43%',
#   '58%',
#   '64%',
#   '46%',
#   '50%',
#   '33%'],
#  ['800000',
#   '210000',
#   '2180000',
#   '7360000',
#   '1610000',
#   '200000',
#   '900000',
#   '3470000',
#   '7470000',
#   '6770000',
#   '7390000',
#   '8960000',
#   '1800000',
#   '11890000',
#   '400000',
#   '17040000',
#   '18510000',
#   '3010000',
#   '13820000',
#   '8930000',
#   '12530000',
#   '11660000',
#   '4710000',
#   '16180000',
#   '16150000',
#   '3740000',
#   '240000',
#   '170000',
#   '180000',
#   '7960000',
#   '870000',
#   '2070000',
#   '200000',
#   '210000',
#   '260000',
#   '5720000',
#   '5880000',
#   '270000',
#   '300000',
#   '4060000',
#   '1780000',
#   '220000',
#   '310000',
#   '2950000',
#   '170000',
#   '1020000',
#   '12870000',
#   '8850000',
#   '4480000',
#   '9280000',
#   '310000',
#   '4700000',
#   '3380000',
#   '10880000',
#   '3810000',
#   '4460000',
#   '3450000',
#   '13250000',
#   '1830000',
#   '2000000',
#   '170000',
#   '160000',
#   '400000',
#   '6730000',
#   '300000',
#   '2810000',
#   '1140000',
#   '2620000',
#   '830000',
#   '3290000',
#   '200000',
#   '180000',
#   '3950000',
#   '210000',
#   '1040000',
#   '2710000',
#   '4830000',
#   '3740000',
#   '15890000',
#   '1910000',
#   '3610000',
#   '1710000',
#   '1180000',
#   '8900000',
#   '12550000',
#   '4320000',
#   '170000',
#   '580000',
#   '250000',
#   '170000',
#   '1750000',
#   '2920000',
#   '5150000',
#   '3460000',
#   '4450000',
#   '320000',
#   '2560000',
#   '2190000',
#   '2030000',
#   '7920000',
#   '210000',
#   '11620000',
#   '10170000',
#   '3850000',
#   '1250000',
#   '5260000',
#   '3960000',
#   '1840000',
#   '7870000',
#   '14500000',
#   '1430000',
#   '11340000',
#   '170000',
#   '240000',
#   '2850000',
#   '1770000',
#   '2220000',
#   '1740000',
#   '2170000',
#   '2790000',
#   '600000',
#   '770000',
#   '1120000',
#   '430000',
#   '1920000',
#   '860000',
#   '490000',
#   '260000',
#   '2660000',
#   '620000',
#   '570000',
#   '240000',
#   '5800000',
#   '2830000',
#   '8580000',
#   '2020000',
#   '590000',
#   '1490000',
#   '210000',
#   '3700000',
#   '250000',
#   '170000',
#   '190000',
#   '220000',
#   '1540000',
#   '170000',
#   '3700000',
#   '4070000',
#   '7310000',
#   '4280000',
#   '390000',
#   '360000',
#   '210000',
#   '1900000',
#   '250000',
#   '3120000',
#   '670000',
#   '2620000',
#   '580000',
#   '3070000',
#   '16410000',
#   '4860000',
#   '1330000',
#   '9400000',
#   '3470000',
#   '640000',
#   '220000',
#   '160000',
#   '1120000',
#   '200000',
#   '670000',
#   '220000',
#   '220000',
#   '390000',
#   '1620000',
#   '1020000',
#   '430000',
#   '1340000',
#   '3890000',
#   '5420000',
#   '480000',
#   '850000',
#   '220000',
#   '1950000',
#   '1800000',
#   '5080000',
#   '8550000',
#   '800000',
#   '310000',
#   '2510000',
#   '330000',
#   '1170000',
#   '260000',
#   '900000',
#   '4670000',
#   '990000',
#   '170000',
#   '1450000',
#   '300000',
#   '1550000',
#   '5880000',
#   '830000',
#   '690000',
#   '1460000',
#   '2590000',
#   '560000',
#   '1050000',
#   '2960000',
#   '4500000',
#   '1280000',
#   '190000',
#   '330000',
#   '600000',
#   '2440000',
#   '690000',
#   '350000',
#   '230000',
#   '190000',
#   '2540000',
#   '3240000',
#   '4960000',
#   '290000',
#   '170000',
#   '170000',
#   '160000',
#   '2990000',
#   '200000',
#   '5440000',
#   '780000',
#   '380000',
#   '6080000',
#   '270000',
#   '1940000',
#   '300000',
#   '1220000',
#   '1060000',
#   '1170000',
#   '360000',
#   '230000',
#   '300000',
#   '570000',
#   '5020000',
#   '6900000',
#   '1570000',
#   '3440000',
#   '3510000',
#   '9030000',
#   '550000',
#   '500000',
#   '4160000',
#   '3350000',
#   '8640000',
#   '160000',
#   '170000',
#   '660000',
#   '4920000',
#   '1910000',
#   '190000',
#   '10130000',
#   '1510000',
#   '560000',
#   '4760000',
#   '410000',
#   '230000',
#   '2090000',
#   '190000',
#   '4710000',
#   '6470000',
#   '4510000',
#   '190000',
#   '15380000',
#   '190000',
#   '190000',
#   '1250000',
#   '3830000',
#   '420000',
#   '190000',
#   '670000',
#   '700000',
#   '9230000',
#   '260000',
#   '13350000',
#   '5550000',
#   '310000',
#   '200000',
#   '2460000',
#   '170000',
#   '2070000',
#   '670000',
#   '1100000',
#   '750000',
#   '190000',
#   '2270000',
#   '650000',
#   '1870000',
#   '2910000',
#   '3850000',
#   '2880000',
#   '190000',
#   '9370000',
#   '3410000',
#   '180000',
#   '2130000',
#   '8070000',
#   '11160000',
#   '3010000',
#   '3100000',
#   '200000',
#   '310000',
#   '13660000',
#   '360000',
#   '1690000',
#   '1720000',
#   '3880000',
#   '160000',
#   '160000',
#   '340000',
#   '410000',
#   '190000',
#   '1360000',
#   '4060000',
#   '290000',
#   '6730000',
#   '3000000',
#   '1680000',
#   '450000',
#   '890000',
#   '4530000',
#   '590000',
#   '420000',
#   '11620000',
#   '2430000',
#   '2380000',
#   '3470000',
#   '350000',
#   '920000',
#   '1590000',
#   '4970000',
#   '350000',
#   '3850000',
#   '4990000',
#   '2070000',
#   '170000',
#   '170000',
#   '2450000',
#   '180000',
#   '370000',
#   '180000',
#   '790000',
#   '220000',
#   '200000',
#   '1000000',
#   '370000',
#   '290000',
#   '3510000',
#   '860000',
#   '1630000',
#   '400000',
#   '940000',
#   '350000',
#   '2480000',
#   '4390000',
#   '880000',
#   '250000',
#   '210000',
#   '1360000',
#   '1300000',
#   '180000',
#   '360000',
#   '2160000',
#   '4840000',
#   '1790000',
#   '170000',
#   '2680000',
#   '320000',
#   '160000',
#   '520000',
#   '1380000',
#   '2350000',
#   '190000',
#   '210000',
#   '480000',
#   '1330000',
#   '700000',
#   '770000',
#   '1430000',
#   '280000',
#   '1220000',
#   '720000',
#   '680000',
#   '180000',
#   '530000',
#   '1540000',
#   '3530000',
#   '860000',
#   '750000',
#   '180000',
#   '4320000',
#   '690000',
#   '260000',
#   '3190000',
#   '4770000',
#   '170000',
#   '160000',
#   '950000',
#   '210000',
#   '1690000',
#   '8190000',
#   '2320000',
#   '200000',
#   '6130000',
#   '830000',
#   '490000',
#   '1600000',
#   '300000',
#   '700000',
#   '380000',
#   '2240000',
#   '550000',
#   '4810000',
#   '290000',
#   '6730000',
#   '3680000',
#   '900000',
#   '350000',
#   '290000',
#   '3170000',
#   '610000',
#   '5950000',
#   '190000',
#   '610000',
#   '160000',
#   '1660000',
#   '170000',
#   '220000',
#   '1920000',
#   '370000',
#   '800000',
#   '200000',
#   '1810000',
#   '3720000',
#   '1230000',
#   '230000',
#   '410000',
#   '1210000',
#   '2040000',
#   '220000',
#   '1130000',
#   '3330000',
#   '530000',
#   '2950000',
#   '1140000',
#   '210000',
#   '290000',
#   '1730000',
#   '660000',
#   '7400000',
#   '3490000',
#   '240000',
#   '180000',
#   '240000',
#   '160000',
#   '1010000',
#   '1270000',
#   '260000',
#   '720000',
#   '270000',
#   '250000',
#   '1320000',
#   '1940000',
#   '690000',
#   '1280000',
#   '980000',
#   '350000',
#   '390000',
#   '1410000',
#   '1160000',
#   '380000',
#   '620000',
#   '200000',
#   '1680000',
#   '2620000',
#   '850000',
#   '730000',
#   '400000',
#   '390000',
#   '3330000',
#   '500000',
#   '1400000',
#   '1670000',
#   '160000',
#   '1950000',
#   '160000',
#   '160000',
#   '190000',
#   '370000',
#   '1770000',
#   '230000',
#   '380000',
#   '780000',
#   '2480000',
#   '1110000',
#   '5320000',
#   '2340000',
#   '2940000',
#   '660000',
#   '220000',
#   '2480000',
#   '840000',
#   '530000',
#   '1300000',
#   '560000',
#   '330000',
#   '8170000',
#   '13510000',
#   '1250000'],
#  ['FC Bayern München',
#   'FC Bayern München',
#   'FC Bayern München',
#   'FC Bayern München',
#   'FC Bayern München',
#   'FC Bayern München',
#   'FC Bayern München',
#   'FC Bayern München',
#   'FC Bayern München',
#   'FC Bayern München',
#   'FC Bayern München',
#   'FC Bayern München',
#   'FC Bayern München',
#   'FC Bayern München',
#   'FC Bayern München',
#   'FC Bayern München',
#   'FC Bayern München',
#   'FC Bayern München',
#   'FC Bayern München',
#   'FC Bayern München',
#   'FC Bayern München',
#   'FC Bayern München',
#   'FC Bayern München',
#   'FC Bayern München',
#   'FC Bayern München',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Borussia Dortmund',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'Bayer Leverkusen',
#   'RB Leipzig',
#   'RB Leipzig',
#   'RB Leipzig',
#   'RB Leipzig',
#   'RB Leipzig',
#   'RB Leipzig',
#   'RB Leipzig',
#   'RB Leipzig',
#   'RB Leipzig',
#   'RB Leipzig',
#   'RB Leipzig',
#   'RB Leipzig',
#   'RB Leipzig',
#   'RB Leipzig',
#   'RB Leipzig',
#   'RB Leipzig',
#   'RB Leipzig',
#   'RB Leipzig',
#   'RB Leipzig',
#   'RB Leipzig',
#   'RB Leipzig',
#   'RB Leipzig',
#   'RB Leipzig',
#   'RB Leipzig',
#   'RB Leipzig',
#   'RB Leipzig',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'FC Union Berlin',
#   'SC Freiburg',
#   'SC Freiburg',
#   'SC Freiburg',
#   'SC Freiburg',
#   'SC Freiburg',
#   'SC Freiburg',
#   'SC Freiburg',
#   'SC Freiburg',
#   'SC Freiburg',
#   'SC Freiburg',
#   'SC Freiburg',
#   'SC Freiburg',
#   'SC Freiburg',
#   'SC Freiburg',
#   'SC Freiburg',
#   'SC Freiburg',
#   'SC Freiburg',
#   'SC Freiburg',
#   'SC Freiburg',
#   'SC Freiburg',
#   'SC Freiburg',
#   'SC Freiburg',
#   'SC Freiburg',
#   'SC Freiburg',
#   'SC Freiburg',
#   'SC Freiburg',
#   'SC Freiburg',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FC Köln',
#   'FSV Mainz 05',
#   'FSV Mainz 05',
#   'FSV Mainz 05',
#   'FSV Mainz 05',
#   'FSV Mainz 05',
#   'FSV Mainz 05',
#   'FSV Mainz 05',
#   'FSV Mainz 05',
#   'FSV Mainz 05',
#   'FSV Mainz 05',
#   'FSV Mainz 05',
#   'FSV Mainz 05',
#   'FSV Mainz 05',
#   'FSV Mainz 05',
#   'FSV Mainz 05',
#   'FSV Mainz 05',
#   'FSV Mainz 05',
#   'FSV Mainz 05',
#   'FSV Mainz 05',
#   'FSV Mainz 05',
#   'FSV Mainz 05',
#   'FSV Mainz 05',
#   'FSV Mainz 05',
#   'FSV Mainz 05',
#   'FSV Mainz 05',
#   'FSV Mainz 05',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   'TSG Hoffenheim',
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   "Borussioa M'Gladbach",
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'Eintrach Frankfurt',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Wolfsburg',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'VfL Bochum',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'FC Augsburg',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'VfB Stuttgart',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'Hertha BSC',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'FC Schalke 04',
#   'SV Werder Bremen',
#   'SV Werder Bremen',
#   'SV Werder Bremen',
#   'SV Werder Bremen',
#   'SV Werder Bremen',
#   'SV Werder Bremen',
#   'SV Werder Bremen',
#   'SV Werder Bremen',
#   'SV Werder Bremen',
#   'SV Werder Bremen',
#   'SV Werder Bremen',
#   'SV Werder Bremen',
#   'SV Werder Bremen',
#   'SV Werder Bremen',
#   'SV Werder Bremen',
#   'SV Werder Bremen',
#   'SV Werder Bremen',
#   'SV Werder Bremen',
#   'SV Werder Bremen',
#   'SV Werder Bremen',
#   'SV Werder Bremen',
#   'SV Werder Bremen',
#   'SV Werder Bremen',
#   'SV Werder Bremen',
#   'SV Werder Bremen',
#   'SV Werder Bremen'],
#  ['11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023',
#   '11/01/2023'])

# %%
df = pd.DataFrame(playerid, columns=['Playerid'])
df['Datum'] = pd.Series(datum)
df['Verein'] = pd.Series(verein)
df['Name'] = pd.Series(playername)
df['Position'] = pd.Series(position)
df['Punkte'] = pd.Series(punkte)
df['Punkte pro Spiel'] = pd.Series(pps)
df['Passquote'] = pd.Series(passq)
df['Zweikampf'] = pd.Series(zweikampf)
df['Marktwert'] = pd.Series(marktwert)

# %%
tag = date.today().strftime('%d/%m/%Y')
tag = tag.replace("/", "_")
tag
# Out:
# '11_01_2023'

# %%
df.to_csv(str(tag) + ".csv", index=False)

# %%
# !pip install apache-airflow
# Out:
# Requirement already satisfied: apache-airflow in c:\users\sprav\anaconda3\lib\site-packages (2.5.0)
# Requirement already satisfied: alembic<2.0,>=1.6.3 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (1.9.1)
# Requirement already satisfied: sqlalchemy>=1.4 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (1.4.39)
# Requirement already satisfied: psutil>=4.2.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (5.9.0)
# Requirement already satisfied: pygments>=2.0.1 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (2.11.2)
# Requirement already satisfied: deprecated>=1.2.13 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (1.2.13)
# Requirement already satisfied: markdown>=3.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (3.3.4)
# Requirement already satisfied: cryptography>=0.9.3 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (3.4.8)
# Requirement already satisfied: graphviz>=0.12 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (0.20.1)
# Requirement already satisfied: tabulate>=0.7.5 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (0.8.10)
# Requirement already satisfied: apache-airflow-providers-http in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (4.1.0)
# Requirement already satisfied: jinja2>=3.0.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (3.1.2)
# Requirement already satisfied: pluggy>=1.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (1.0.0)
# Requirement already satisfied: python-nvd3>=0.15.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (0.15.0)
# Requirement already satisfied: unicodecsv>=0.14.1 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (0.14.1)
# Requirement already satisfied: flask<2.3,>=2.2 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (2.2.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (8.0.1)
# Requirement already satisfied: apache-airflow-providers-sqlite in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (3.3.1)
# Requirement already satisfied: httpx in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (0.23.1)
# Requirement already satisfied: pendulum>=2.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (2.1.2)
# Requirement already satisfied: markupsafe>=1.1.1 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (2.1.1)
# Requirement already satisfied: flask-login>=0.6.2 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (0.6.2)
# Requirement already satisfied: marshmallow-oneofschema>=2.0.1 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (3.0.1)
# Requirement already satisfied: blinker in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (1.5)
# Requirement already satisfied: flask-caching>=1.5.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (2.0.1)
# Requirement already satisfied: markdown-it-py>=2.1.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (2.1.0)
# Requirement already satisfied: rich>=12.4.4 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (12.6.0)
# Requirement already satisfied: dill>=0.2.2 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (0.3.4)
# Requirement already satisfied: colorlog<5.0,>=4.0.2 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (4.8.0)
# Requirement already satisfied: flask-wtf>=0.15 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (1.0.1)
# Requirement already satisfied: setproctitle>=1.1.8 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (1.3.2)
# Requirement already satisfied: apache-airflow-providers-common-sql in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (1.3.1)
# Requirement already satisfied: flask-session>=0.4.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.3 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (2.8.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (2.0.1)
# Requirement already satisfied: linkify-it-py>=2.0.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (2.0.0)
# Requirement already satisfied: pyjwt>=2.0.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (2.3.0)
# Requirement already satisfied: python-daemon>=2.2.4 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (2.3.2)
# Requirement already satisfied: apache-airflow-providers-imap in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (4.3.0)
# Requirement already satisfied: cron-descriptor>=1.2.24 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (1.2.32)
# Requirement already satisfied: connexion[flask,swagger-ui]>=2.10.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (2.14.1)
# Requirement already satisfied: gunicorn>=20.1.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (20.1.0)
# Requirement already satisfied: attrs>=22.1.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (22.2.0)
# Requirement already satisfied: jsonschema>=3.2.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (4.16.0)
# Requirement already satisfied: packaging>=14.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (21.3)
# Requirement already satisfied: sqlalchemy-jsonfield>=1.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (1.0.1.post0)
# Requirement already satisfied: apache-airflow-providers-ftp in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (3.2.0)
# Requirement already satisfied: werkzeug>=2.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (2.2.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (2.1.1)
# Requirement already satisfied: pathspec~=0.9.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (0.9.0)
# Requirement already satisfied: cattrs>=22.1.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (22.2.0)
# Requirement already satisfied: argcomplete>=1.10 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (2.0.0)
# Requirement already satisfied: configupdater>=3.1.1 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (3.1.1)
# Requirement already satisfied: flask-appbuilder==4.1.4 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (4.1.4)
# Requirement already satisfied: mdit-py-plugins>=0.3.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (0.3.3)
# Requirement already satisfied: lazy-object-proxy in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (1.6.0)
# Requirement already satisfied: python-slugify>=5.0 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (5.0.2)
# Requirement already satisfied: croniter>=0.3.17 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (1.3.8)
# Requirement already satisfied: lockfile>=0.12.2 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow) (0.12.2)
# Requirement already satisfied: WTForms<4 in c:\users\sprav\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (3.0.1)
# Requirement already satisfied: click<9,>=8 in c:\users\sprav\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (8.0.4)
# Requirement already satisfied: apispec[yaml]<4,>=3.3 in c:\users\sprav\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (3.3.2)
# Requirement already satisfied: email-validator<2,>=1.0.5 in c:\users\sprav\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (1.3.0)
# Requirement already satisfied: Flask-Babel<3,>=1 in c:\users\sprav\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (2.0.0)
# Requirement already satisfied: marshmallow-sqlalchemy<0.27.0,>=0.22.0 in c:\users\sprav\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (0.26.1)
# Requirement already satisfied: Flask-JWT-Extended<5.0.0,>=4.0.0 in c:\users\sprav\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (4.4.4)
# Requirement already satisfied: sqlalchemy-utils<1,>=0.32.21 in c:\users\sprav\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (0.39.0)
# Requirement already satisfied: prison<1.0.0,>=0.2.1 in c:\users\sprav\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (0.2.1)
# Requirement already satisfied: marshmallow-enum<2,>=1.5.1 in c:\users\sprav\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (1.5.1)
# Requirement already satisfied: Flask-SQLAlchemy<3,>=2.4 in c:\users\sprav\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (2.5.1)
# Requirement already satisfied: colorama<1,>=0.3.9 in c:\users\sprav\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (0.4.5)
# Requirement already satisfied: marshmallow<4,>=3 in c:\users\sprav\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (3.19.0)
# Requirement already satisfied: Mako in c:\users\sprav\anaconda3\lib\site-packages (from alembic<2.0,>=1.6.3->apache-airflow) (1.2.4)
# Requirement already satisfied: exceptiongroup in c:\users\sprav\anaconda3\lib\site-packages (from cattrs>=22.1.0->apache-airflow) (1.1.0)
# Requirement already satisfied: clickclick<21,>=1.2 in c:\users\sprav\anaconda3\lib\site-packages (from connexion[flask,swagger-ui]>=2.10.0->apache-airflow) (20.10.2)
# Requirement already satisfied: PyYAML<7,>=5.1 in c:\users\sprav\anaconda3\lib\site-packages (from connexion[flask,swagger-ui]>=2.10.0->apache-airflow) (6.0)
# Requirement already satisfied: inflection<0.6,>=0.3.1 in c:\users\sprav\anaconda3\lib\site-packages (from connexion[flask,swagger-ui]>=2.10.0->apache-airflow) (0.5.1)
# Requirement already satisfied: requests<3,>=2.9.1 in c:\users\sprav\anaconda3\lib\site-packages (from connexion[flask,swagger-ui]>=2.10.0->apache-airflow) (2.26.0)
# Requirement already satisfied: swagger-ui-bundle<0.1,>=0.0.2 in c:\users\sprav\anaconda3\lib\site-packages (from connexion[flask,swagger-ui]>=2.10.0->apache-airflow) (0.0.9)
# Requirement already satisfied: cffi>=1.12 in c:\users\sprav\anaconda3\lib\site-packages (from cryptography>=0.9.3->apache-airflow) (1.15.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\sprav\anaconda3\lib\site-packages (from deprecated>=1.2.13->apache-airflow) (1.14.1)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\sprav\anaconda3\lib\site-packages (from flask<2.3,>=2.2->apache-airflow) (4.11.3)
# Requirement already satisfied: cachelib>=0.9.0 in c:\users\sprav\anaconda3\lib\site-packages (from flask-caching>=1.5.0->apache-airflow) (0.9.0)
# Requirement already satisfied: setuptools>=3.0 in c:\users\sprav\anaconda3\lib\site-packages (from gunicorn>=20.1.0->apache-airflow) (63.4.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\sprav\anaconda3\lib\site-packages (from jsonschema>=3.2.0->apache-airflow) (0.18.0)
# Requirement already satisfied: uc-micro-py in c:\users\sprav\anaconda3\lib\site-packages (from linkify-it-py>=2.0.0->apache-airflow) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sprav\anaconda3\lib\site-packages (from markdown-it-py>=2.1.0->apache-airflow) (0.1.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\sprav\anaconda3\lib\site-packages (from packaging>=14.0->apache-airflow) (3.0.9)
# Requirement already satisfied: pytzdata>=2020.1 in c:\users\sprav\anaconda3\lib\site-packages (from pendulum>=2.0->apache-airflow) (2020.1)
# Requirement already satisfied: docutils in c:\users\sprav\anaconda3\lib\site-packages (from python-daemon>=2.2.4->apache-airflow) (0.18.1)
# Requirement already satisfied: six>=1.5 in c:\users\sprav\anaconda3\lib\site-packages (from python-dateutil>=2.3->apache-airflow) (1.16.0)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\sprav\anaconda3\lib\site-packages (from python-slugify>=5.0->apache-airflow) (1.3)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\sprav\anaconda3\lib\site-packages (from rich>=12.4.4->apache-airflow) (0.9.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\sprav\anaconda3\lib\site-packages (from sqlalchemy>=1.4->apache-airflow) (1.1.1)
# Requirement already satisfied: sqlparse>=0.4.2 in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow-providers-common-sql->apache-airflow) (0.4.3)
# Requirement already satisfied: requests-toolbelt in c:\users\sprav\anaconda3\lib\site-packages (from apache-airflow-providers-http->apache-airflow) (0.10.1)
# Requirement already satisfied: sniffio in c:\users\sprav\anaconda3\lib\site-packages (from httpx->apache-airflow) (1.2.0)
# Requirement already satisfied: certifi in c:\users\sprav\anaconda3\lib\site-packages (from httpx->apache-airflow) (2021.10.8)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in c:\users\sprav\anaconda3\lib\site-packages (from httpx->apache-airflow) (1.5.0)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in c:\users\sprav\anaconda3\lib\site-packages (from httpx->apache-airflow) (0.16.3)
# Requirement already satisfied: pycparser in c:\users\sprav\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=0.9.3->apache-airflow) (2.21)
# Requirement already satisfied: idna>=2.0.0 in c:\users\sprav\anaconda3\lib\site-packages (from email-validator<2,>=1.0.5->flask-appbuilder==4.1.4->apache-airflow) (3.3)
# Requirement already satisfied: dnspython>=1.15.0 in c:\users\sprav\anaconda3\lib\site-packages (from email-validator<2,>=1.0.5->flask-appbuilder==4.1.4->apache-airflow) (2.2.1)
# Requirement already satisfied: Babel>=2.3 in c:\users\sprav\anaconda3\lib\site-packages (from Flask-Babel<3,>=1->flask-appbuilder==4.1.4->apache-airflow) (2.9.1)
# Requirement already satisfied: pytz in c:\users\sprav\anaconda3\lib\site-packages (from Flask-Babel<3,>=1->flask-appbuilder==4.1.4->apache-airflow) (2022.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\sprav\anaconda3\lib\site-packages (from httpcore<0.17.0,>=0.15.0->httpx->apache-airflow) (3.5.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sprav\anaconda3\lib\site-packages (from httpcore<0.17.0,>=0.15.0->httpx->apache-airflow) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\sprav\anaconda3\lib\site-packages (from importlib-metadata>=3.6.0->flask<2.3,>=2.2->apache-airflow) (3.8.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sprav\anaconda3\lib\site-packages (from requests<3,>=2.9.1->connexion[flask,swagger-ui]>=2.10.0->apache-airflow) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sprav\anaconda3\lib\site-packages (from requests<3,>=2.9.1->connexion[flask,swagger-ui]>=2.10.0->apache-airflow) (2.0.12)
# WARNING: Ignoring invalid distribution -ffi (c:\users\sprav\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\sprav\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\sprav\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\sprav\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\sprav\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\sprav\anaconda3\lib\site-packages)

# %%
# !airflow db init
# Out:
# DB: sqlite:///C:\Users\SPrav/airflow/airflow.db
# [2023-01-11 22:57:20,516] {migration.py:205} INFO - Context impl SQLiteImpl.
# [2023-01-11 22:57:20,516] {migration.py:208} INFO - Will assume non-transactional DDL.
# [2023-01-11 22:57:20,641] {migration.py:205} INFO - Context impl SQLiteImpl.
# [2023-01-11 22:57:20,641] {migration.py:208} INFO - Will assume non-transactional DDL.
# [2023-01-11 22:57:20,643] {db.py:1570} INFO - Creating tables
# Initialization done
# C:\Users\SPrav\anaconda3\lib\site-packages\airflow\cli\cli_parser.py:905 DeprecationWarning: The namespace option in [kubernetes] has been moved to the namespace option in [kubernetes_executor] - the old setting has been used, but please update your config.
# C:\Users\SPrav\anaconda3\lib\configparser.py:408 FutureWarning: The config section [kubernetes] has been renamed to [kubernetes_executor]. Please update your `conf.get*` call to use the new name
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Running upgrade ecb43d2a1842 -> b0d31815b5a6, Add missing auto-increment to columns on FAB tables
# INFO  [alembic.runtime.migration] Running upgrade b0d31815b5a6 -> e07f49787c9d, Add case-insensitive unique constraint for username
# INFO  [alembic.runtime.migration] Running upgrade e07f49787c9d -> ee8d93fcc81e, Add updated_at column to DagRun and TaskInstance
# INFO  [alembic.runtime.migration] Running upgrade ee8d93fcc81e -> 1986afd32c1b, Add DagRunNote and TaskInstanceNote
# INFO  [alembic.runtime.migration] Running upgrade 1986afd32c1b -> 290244fb8b83, Add is_orphaned to DatasetModel
# WARNI [airflow.task.operators] Dependency <Task(BashOperator): create_entry_group>, delete_entry_group already registered for DAG: example_complex
# WARNI [airflow.task.operators] Dependency <Task(BashOperator): delete_entry_group>, create_entry_group already registered for DAG: example_complex
# WARNI [airflow.task.operators] Dependency <Task(BashOperator): create_entry_gcs>, delete_entry already registered for DAG: example_complex
# WARNI [airflow.task.operators] Dependency <Task(BashOperator): delete_entry>, create_entry_gcs already registered for DAG: example_complex
# WARNI [airflow.task.operators] Dependency <Task(BashOperator): create_tag>, delete_tag already registered for DAG: example_complex
# WARNI [airflow.task.operators] Dependency <Task(BashOperator): delete_tag>, create_tag already registered for DAG: example_complex
# WARNI [airflow.task.operators] Dependency <Task(_PythonDecoratedOperator): prepare_email>, send_email already registered for DAG: example_dag_decorator
# WARNI [airflow.task.operators] Dependency <Task(EmailOperator): send_email>, prepare_email already registered for DAG: example_dag_decorator
# C:\Users\SPrav\anaconda3\lib\configparser.py:408 FutureWarning: The config section [kubernetes] has been renamed to [kubernetes_executor]. Please update your `conf.get*` call to use the new name
# WARNI [unusual_prefix_d40d5574971d924c0610a7538f6342257f7e2f7e_example_kubernetes_executor] The example_kubernetes_executor example DAG requires the kubernetes provider. Please install it with: pip install apache-airflow[cncf.kubernetes]
# WARNI [unusual_prefix_1b1a91c366780369a6edef2260528e59792ce8ea_example_local_kubernetes_executor] Could not import DAGs in example_local_kubernetes_executor.py
# Traceback (most recent call last):
#   File "C:\Users\SPrav\anaconda3\lib\site-packages\airflow\example_dags\example_local_kubernetes_executor.py", line 37, in <module>
#     from kubernetes.client import models as k8s
# ModuleNotFoundError: No module named 'kubernetes'
# WARNI [unusual_prefix_1b1a91c366780369a6edef2260528e59792ce8ea_example_local_kubernetes_executor] Install Kubernetes dependencies with: pip install apache-airflow[cncf.kubernetes]
# WARNI [airflow.task.operators] Dependency <Task(_PythonDecoratedOperator): print_the_context>, log_sql_query already registered for DAG: example_python_operator
# WARNI [airflow.task.operators] Dependency <Task(_PythonDecoratedOperator): log_sql_query>, print_the_context already registered for DAG: example_python_operator
# WARNI [airflow.task.operators] Dependency <Task(_PythonDecoratedOperator): print_the_context>, log_sql_query already registered for DAG: example_python_operator
# WARNI [airflow.task.operators] Dependency <Task(_PythonDecoratedOperator): log_sql_query>, print_the_context already registered for DAG: example_python_operator
# WARNI [airflow.task.operators] Dependency <Task(_PythonDecoratedOperator): print_the_context>, log_sql_query already registered for DAG: example_python_operator
# WARNI [airflow.task.operators] Dependency <Task(_PythonDecoratedOperator): log_sql_query>, print_the_context already registered for DAG: example_python_operator
# WARNI [airflow.task.operators] Dependency <Task(_PythonDecoratedOperator): print_the_context>, log_sql_query already registered for DAG: example_python_operator
# WARNI [airflow.task.operators] Dependency <Task(_PythonDecoratedOperator): log_sql_query>, print_the_context already registered for DAG: example_python_operator
# WARNI [unusual_prefix_0607bfd0ab1b4318ddeb27f558c3b41d7a579f00_example_python_operator] The virtalenv_python example task requires virtualenv, please install it.
# C:\Users\SPrav\anaconda3\lib\site-packages\airflow\models\dag.py:3492 RemovedInAirflow3Warning: Param `schedule_interval` is deprecated and will be removed in a future release. Please use `schedule` instead.
# WARNI [unusual_prefix_8642c93a36aa14841aa93e71c519b526eaa18bd1_tutorial_taskflow_api_virtualenv] The tutorial_taskflow_api_virtualenv example DAG requires virtualenv, please install it.
# WARNI [airflow.models.crypto] empty cryptography key - values will not be stored encrypted.

# %%
import airflow
print(airflow.__file__)
# Out:
# c:\Users\SPrav\anaconda3\lib\site-packages\airflow\__init__.py

# %%
# !conda install -c conda-forge ffi
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - ffi
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge/win-64
#   - https://conda.anaconda.org/conda-forge/noarch
#   - https://repo.anaconda.com/pkgs/main/win-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/win-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#   - https://repo.anaconda.com/pkgs/msys2/win-64
#   - https://repo.anaconda.com/pkgs/msys2/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
